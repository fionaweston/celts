# %%
import pandas as pd

# %%
df=pd.read_csv("./Data/parking-citations.csv")
# Out:
# C:\Users\david\anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df_meter=df.loc[df['Meter Id'].notnull(),]
df_meter=df.loc[df['Violation Description']=='METER EXP.',].sort_values(['Meter Id'])

# %%
df.groupby(['Meter Id'])['Meter Id'].count().sort_values(ascending=False)
# Out:
# Meter Id
# 37        49660
# 51        32652
# 53        32605
# 13        29006
# 49        28953
# 64        25888
# 30        24460
# 96        21581
# 36        20709
# 12        16951
# 34        15832
# 46        15263
# 41        14365
# 23        13527
# 26         9965
# 80         9888
# 40         9866
# 15         9756
# 45         9182
# 25         8971
# 81         8825
# 101        8775
# 227        8283
# 31         8159
# 132        8083
# 191        6955
# 537        6824
# 57         6596
# 3          6253
# 99         5564
#           ...
# LMHOA         1
# LM651A        1
# LM6491        1
# LM63          1
# LM525         1
# LM195         1
# LM191         1
# LM188         1
# LL36          1
# LP20          1
# LP21          1
# LP210         1
# LP245         1
# LP56          1
# LP55          1
# LP53          1
# LP303         1
# LP291         1
# LP288         1
# LP284         1
# LP23          1
# LP211         1
# LP227         1
# LP226         1
# ...

# %%
df_meter.head(50)
# Out:
#         Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 6293035    4318996754  2017-10-19T00:00:00      1129.0    16423          NaN
# 6326156    4319650764  2017-10-24T00:00:00      1119.0    16423          NaN
# 6293036    4318996765  2017-10-19T00:00:00      1133.0    16423          NaN
# 6326157    4319650775  2017-10-24T00:00:00      1121.0    16423          NaN
# 6340124    4320276026  2017-10-30T00:00:00      1149.0    16423          NaN
# 6340123    4320276015  2017-10-30T00:00:00      1146.0    16423          NaN
# 6326158    4319650786  2017-10-24T00:00:00      1127.0    16423          NaN
# 6207574    4317754910  2017-10-26T00:00:00      1149.0    16423          NaN
# 6325250    4319632063  2017-10-20T00:00:00       840.0    16423          NaN
# 6353245    4318935386  2017-11-08T00:00:00      1121.0    16423          NaN
# 6320415    4319508034  2017-10-27T00:00:00      1155.0    16423          NaN
# ...

# %%
df.columns
# Out:
# Index(['Ticket number', 'Issue Date', 'Issue time', 'Meter Id', 'Marked Time',
#        'RP State Plate', 'Plate Expiry Date', 'VIN', 'Make', 'Body Style',
#        'Color', 'Location', 'Route', 'Agency', 'Violation code',
#        'Violation Description', 'Fine amount', 'Latitude', 'Longitude'],
#       dtype='object')
