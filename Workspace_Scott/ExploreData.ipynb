# %% [markdown]
# ## LA Citation Data Exploration

# %%
#- Import Dependences
import pandas as pd
import os

# %%
#-- Import CSV
path = "/Users/thefixermac/Development_Data/Workshop/DataScience_Project_3/los-angeles-parking-citations/parking-citations.csv"  



citations = pd.read_csv(path)


citations.head()
# Out:
# /Users/thefixermac/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 0    1103341116  2015-12-21T00:00:00      1251.0      NaN          NaN
# 1    1103700150  2015-12-21T00:00:00      1435.0      NaN          NaN
# 2    1104803000  2015-12-21T00:00:00      2055.0      NaN          NaN
# 3    1104820732  2015-12-26T00:00:00      1515.0      NaN          NaN
# 4    1105461453  2015-09-15T00:00:00       115.0      NaN          NaN
#
#   RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 0             CA           200304.0  NaN  HOND         PA    GY
# 1             CA           201512.0  NaN   GMC         VN    WH
# 2             CA           201503.0  NaN  NISS         PA    BK
# ...

# %%
#- Get Count of records
citations.shape
# Out:
# (9389057, 19)

# %%
#- Column Information
list(citations)
# Out:
# ['Ticket number',
#  'Issue Date',
#  'Issue time',
#  'Meter Id',
#  'Marked Time',
#  'RP State Plate',
#  'Plate Expiry Date',
#  'VIN',
#  'Make',
#  'Body Style',
#  'Color',
#  'Location',
#  'Route',
#  'Agency',
#  'Violation code',
#  'Violation Description',
#  'Fine amount',
#  'Latitude',
#  'Longitude']

# %%
#-- Get Unique values for meter
meterUniqueValues = citations['Meter Id'].unique()

meterUniqueValues
# Out:
# array([nan, 'WF55', 'WF54', ..., 'Y092', 'Y079', 'Y068A'], dtype=object)

# %%
len(meterUniqueValues)
# Out:
# 38003

# %%
#-- Get Counts of unique vlaues
meterUniqueCounts = citations['Meter Id'].value_counts()

meterUniqueCounts
# Out:
# 37        49660
# 51        32652
# 53        32605
# 13        29006
# 49        28953
# 64        25888
# 30        24460
# 96        21581
# 36        20709
# 12        16951
# 34        15832
# 46        15263
# 41        14365
# 23        13527
# 26         9965
# 80         9888
# 40         9866
# 15         9756
# 45         9182
# 25         8971
# 81         8825
# 101        8775
# 227        8283
# 31         8159
# 132        8083
# 191        6955
# 537        6824
# 57         6596
# 3          6253
# 99         5564
#           ...
# CC1133        1
# ED751         1
# SO658         1
# 2494          1
# SEC3C         1
# D48           1
# WW2121        1
# MD56          1
# 1171          1
# S077          1
# VW1623        1
# 128B          1
# CV1223        1
# HO722         1
# 6626          1
# VW67          1
# WA93          1
# 464B          1
# VH117         1
# WW2028        1
# 23R81         1
# RA150         1
# LT484         1
# WV1141        1
# ...

# %%
#-- Filter for individual Meter
subset_df = citations.loc[(citations["Meter Id"] == '37'), :]

subset_df.head()
# Out:
#      Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 1627    4272821663  2015-12-30T00:00:00      1917.0       37          NaN
# 1628    4272821674  2015-12-30T00:00:00      1925.0       37          NaN
# 1629    4272821685  2015-12-30T00:00:00      1930.0       37          NaN
# 3474    4273524345  2015-12-30T00:00:00      1853.0       37          NaN
# 4830    4273805373  2015-12-30T00:00:00         2.0       37          NaN
#
#      RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 1627             CA                6.0  NaN  JEEP         PA    BK
# 1628             CA                NaN  NaN  MNNI         PA    BL
# 1629             CA                3.0  NaN  TSMR         PA    BK
# 3474             CA           201608.0  NaN  TOYT         PA    BK
# 4830             CA           201606.0  NaN  TOYT         PA    WT
#
#                         Location  Route  Agency Violation code  \
# ...

# %%
subset_df.shape
# Out:
# (49660, 19)

# %%
subsetUniqueCounts = subset_df["Location"].value_counts()

subsetUniqueCounts
# Out:
# 7000 HAWTHORN AVE                 3956
# 1665 SYCAMORE AVE N               2338
# 1600 ORANGE DR N                  2109
# 1601 ORANGE DR N                  2024
# 1600 NORTH ORANGE DRIVE           1914
# 1633 ORANGE DR N                  1588
# 1600 ORANGE DR                    1336
# 1633 NORTH ORANGE DRIVE           1231
# 7000 HAWTHORN AVENUE              1140
# 7040 HAWTHORN AVE                 1106
# 7024 HAWTHORN AVE                 1098
# 1664 SYCAMORE AVE N               1056
# 7036 HAWTHORN AVE                 1008
# 1601 NORTH ORANGE DRIVE            881
# 1665 NORTH SYCAMORE AVENUE         753
# 1666 SYCAMORE AVE N                731
# 7044 HAWTHORN AVE                  673
# 1645 ORANGE DR N                   569
# 7000 W HAWTHORN AVE                497
# 7018 HAWTHORN AVE                  478
# 1665 SYCAMORE AVE                  475
# 7036 HAWTHORN AVENUE               457
# 1635 ORANGE DR N                   411
# 1631 ORANGE DR N                   406
# ...

# %%
subsetViolationCounts = subset_df['Violation Description'].value_counts()

subsetViolationCounts
# Out:
# PREFERENTIAL PARKING    49379
# PREF PARKING              195
# OVNIGHT PRK W/OUT PE       83
# OVERNIGHT PARKING           2
# 5204                        1
# Name: Violation Description, dtype: int64

# %%
#-- Meter: Use Marked Time
markedTimeUniqueCounts = citations['Marked Time'].value_counts()

markedTimeUniqueCounts
# Out:
# 800.0     15915
# 900.0      4719
# 1000.0     4717
# 1100.0     4647
# 830.0      3954
# 930.0      3939
# 1130.0     3595
# 1030.0     3517
# 1110.0     3190
# 1115.0     3009
# 1040.0     2919
# 1050.0     2902
# 1055.0     2866
# 1045.0     2863
# 1020.0     2802
# 945.0      2778
# 815.0      2746
# 820.0      2720
# 940.0      2692
# 1145.0     2665
# 805.0      2664
# 1200.0     2613
# 1015.0     2601
# 1120.0     2595
# 840.0      2552
# 955.0      2538
# 950.0      2509
# 920.0      2495
# 1105.0     2492
# 1010.0     2482
#           ...
# 652.0         1
# 1807.0        1
# 1809.0        1
# 2258.0        1
# 136.0         1
# 714.0         1
# 2256.0        1
# 1812.0        1
# 2253.0        1
# 201.0         1
# 202.0         1
# 617.0         1
# 223.0         1
# 234.0         1
# 231.0         1
# 532.0         1
# 536.0         1
# 537.0         1
# 538.0         1
# 541.0         1
# 543.0         1
# 206.0         1
# 554.0         1
# 557.0         1
# ...

# %%
#-- Violation Code: 88.13B+

violationCodeSubset_df = citations.loc[(citations["Violation code"] == '88.13B+'), :]

violationCodeSubset_df.head(20)
# Out:
#     Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 530    4270903991  2015-12-30T00:00:00       807.0    WF192          NaN
# 531    4270904002  2015-12-30T00:00:00       815.0    BF430          NaN
# 551    4271419121  2015-12-30T00:00:00      1220.0   HO6630          NaN
# 552    4271419132  2015-12-30T00:00:00      1223.0   HO6632          NaN
# 558    4271419191  2015-12-30T00:00:00      1244.0    HO966          NaN
# 560    4271419213  2015-12-30T00:00:00      1300.0    HO133          NaN
# 561    4271419224  2015-12-30T00:00:00      1454.0     L233          NaN
# 571    4271459872  2015-12-30T00:00:00      1747.0     LT72          NaN
# 572    4271459883  2015-12-30T00:00:00      1759.0   CC1235          NaN
# 573    4271459894  2015-12-30T00:00:00      1815.0   CB3168          NaN
# 665    4271891783  2015-12-30T00:00:00      1255.0    SW235          NaN
# 669    4271978745  2015-12-30T00:00:00      1108.0    V6127          NaN
# ...

# %%
violationCodeSubset_df.shape
# Out:
# (1620587, 19)

# %%
violationCodeSubset_df['Meter Id'].value_counts()
# Out:
# WP8204     2686
# V27610     2296
# WP8202     1689
# V6125      1688
# V6128      1648
# V6124      1384
# WP8205     1225
# WP8208     1135
# WP8203     1125
# WP8206     1098
# V6126       931
# WP8201      877
# L16940      872
# V6103       866
# V6104       864
# BW101       652
# V6127       597
# VN685A      589
# V6120       586
# V6105       585
# V6106       537
# GA22        518
# V6123       507
# GA22A       502
# CB156       488
# CB2189      482
# V77         481
# CB2547      471
# VN687       466
# CB2546      465
#            ...
# LC266A        1
# CB92          1
# MM24          1
# WU106         1
# WN74          1
# WA1164        1
# LC263         1
# VM129         1
# P2            1
# ED468         1
# PB294         1
# C47           1
# CB1066A       1
# CB597A        1
# LH297         1
# SO389         1
# TZ359         1
# EN702         1
# WF37          1
# CC266         1
# CC951A        1
# SO640         1
# WW1522        1
# VW123         1
# ...

# %%
#-- Filter for individual Meter
subsetMeter_df = citations.loc[(citations["Meter Id"] == 'WP8204'), :]

subsetMeter_df.head(30)
# Out:
#       Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 1747     4272935251  2015-12-30T00:00:00      1633.0   WP8204          NaN
# 1748     4272935262  2015-12-30T00:00:00      1649.0   WP8204          NaN
# 1762     4272935424  2015-12-30T00:00:00      1949.0   WP8204          NaN
# 2110     4273114731  2015-12-30T00:00:00      1728.0   WP8204          NaN
# 5277     4273892932  2015-12-30T00:00:00      1331.0   WP8204          NaN
# 5278     4273892943  2015-12-30T00:00:00      1332.0   WP8204          NaN
# 5279     4273892954  2015-12-30T00:00:00      1333.0   WP8204          NaN
# 5286     4273893024  2015-12-30T00:00:00      1403.0   WP8204          NaN
# 9708     4273301594  2015-12-31T00:00:00      1431.0   WP8204          NaN
# 13369    4274122274  2015-12-31T00:00:00      1225.0   WP8204          NaN
# 13373    4274122311  2015-12-31T00:00:00      1449.0   WP8204          NaN
# ...

# %%
subsetMeter_df['Location'].value_counts()
# Out:
# 20 WASHINGTON BLVD E    2578
# 16 WASHINGTON BLVD E      96
# 22 WASHINGTON BLVD E      57
# 14 WASHINGTON BLVD E      34
# 15 WASHINGTON BLVD E       1
# 18 WASHINGTON BLVD E       1
# 23 WASHINGTON BLVD E       1
# Name: Location, dtype: int64

# %%
subsetMeter_df['Make'].value_counts()
# Out:
# TOYT    386
# FORD    296
# CHEV    244
# NISS    230
# HOND    180
# HYUN    146
# JEEP    117
# DODG    116
# VOLK    113
# MERZ    112
# BMW     102
# KIA      86
# CHRY     67
# AUDI     66
# MAZD     53
# LEXS     51
# GMC      35
# INFI     34
# SUBA     32
# HD       26
# CADI     26
# VOLV     25
# MITS     20
# MNNI     20
# LNDR     18
# LINC     16
# RROV     14
# BUIC     14
# PORS     14
# ACUR     12
# FIAT     10
# UNK       9
# PONT      9
# OTHR      8
# JAGU      8
# MERC      7
# TSMR      6
# SUZI      5
# ISU       5
# OLDS      5
# KAWK      4
# YAMA      4
# MASE      4
# STRN      4
# SAA       2
# GEO       1
# HUMM      1
# STLG      1
# SMRT      1
# CHEC      1
# IND       1
# FERR      1
# Name: Make, dtype: int64

# %%
subsetMeter_df['Color'].value_counts()
# Out:
# BK    671
# WT    550
# GY    528
# SL    408
# BL    222
# RD    205
# GN     42
# MR     36
# GO     33
# YE     16
# TN     13
# BN     12
# BG      9
# OT      7
# OR      6
# PR      4
# CO      3
# UN      2
# PK      1
# Name: Color, dtype: int64

# %%
##- Subset by Agency
subsetHollywood_df = citations.loc[(citations["Agency"] == 4), :]

subsetHollywood_df.head(20)
# Out:
#       Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 18603    1109077314  2015-12-16T00:00:00      1731.0      NaN          NaN
# 18604    1109077325  2015-12-16T00:00:00      1735.0      NaN          NaN
# 18605    1109077336  2015-12-18T00:00:00      1728.0      NaN          NaN
# 18606    1109077340  2015-12-18T00:00:00      1731.0      NaN          NaN
# 18607    1109077351  2015-12-18T00:00:00      1738.0      NaN          NaN
# 18608    1109078633  2015-12-15T00:00:00      1806.0      NaN          NaN
# 18609    1109078644  2015-12-17T00:00:00      1812.0      NaN          NaN
# 18610    1109078655  2015-12-17T00:00:00      1809.0      NaN          NaN
# 18611    1109078666  2015-12-17T00:00:00      1810.0      NaN          NaN
# 18612    1109078670  2015-12-17T00:00:00      1830.0      NaN          NaN
# 18613    1109079635  2015-12-13T00:00:00      1649.0      NaN          NaN
# ...

# %%
subsetHollywood_df.shape
# Out:
# (28309, 19)

# %%
#-- Determine any Meters for Hollywood
violationCodeSubsetHollywood_df = subsetHollywood_df.loc[(subsetHollywood_df["Violation code"] == '88.13B+'), :]

violationCodeSubsetHollywood_df.head(20)
# Out:
#         Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 6343150    4307014250  2017-11-06T00:00:00      1418.0    80111          NaN
# 6343151    4307020303  2017-11-21T00:00:00      1533.0    80101          NaN
# 6343152    4307020314  2017-11-21T00:00:00      1536.0    80101          NaN
# 6343153    4307020325  2017-11-21T00:00:00      1539.0    80101          NaN
# 6343546    4313006213  2017-11-12T00:00:00      1238.0    80111          NaN
# 6511446    4307014294  2017-12-08T00:00:00      1305.0    80101          NaN
# 6511447    4307014305  2017-12-08T00:00:00      1313.0    80101          NaN
# 6511452    4307014386  2017-12-28T00:00:00      1456.0    80111          NaN
# 6511453    4307014390  2017-12-28T00:00:00      1512.0    80111          NaN
# 6511462    4307020410  2017-12-21T00:00:00      1457.0    90117          NaN
# 6511463    4307020421  2017-12-21T00:00:00      1504.0    90117          NaN
# ...

# %%
violationCodeSubsetHollywood_df.shape
# Out:
# (78, 19)

# %%
#-- Explorer Other Agencies
subsetWestern_df = citations.loc[(citations["Agency"] == 51), :]

subsetWestern_df.head()
# Out:
#     Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 329    1113879756  2015-12-24T00:00:00      1836.0      NaN          NaN
# 330    1113879760  2015-12-24T00:00:00      1844.0      NaN          NaN
# 331    1113879771  2015-12-24T00:00:00      1848.0      NaN          NaN
# 332    1113879782  2015-12-24T00:00:00      1849.0      NaN          NaN
# 333    1113879793  2015-12-24T00:00:00      1850.0      NaN          NaN
#
#     RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 329             CA           201609.0  NaN  LEXU         PA    GY
# 330             CA           201606.0  NaN  LEXU         PA    GY
# 331             CA           201604.0  NaN  TOYO         PA    GY
# 332             CA           201604.0  NaN  TOYO         PA    BK
# 333             CA           201610.0  NaN  LINC         PA    BK
#
#                  Location  Route  Agency Violation code Violation Description  \
# ...

# %%
subsetWestern_df.shape
# Out:
# (2081757, 19)

# %%
violationCodeSubsetWestern_df = subsetWestern_df.loc[(subsetWestern_df["Violation code"] == '88.13B+'), :]

violationCodeSubsetWestern_df.head(20)
# Out:
#     Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 669    4271978745  2015-12-30T00:00:00      1108.0    V6127          NaN
# 670    4271978756  2015-12-30T00:00:00      1116.0   V27610          NaN
# 671    4271978760  2015-12-30T00:00:00      1122.0     V117          NaN
# 672    4271978771  2015-12-30T00:00:00      1131.0   V27610          NaN
# 673    4271978793  2015-12-30T00:00:00      1140.0    V6125          NaN
# 674    4271978804  2015-12-30T00:00:00      1151.0      V74          NaN
# 676    4271978826  2015-12-30T00:00:00      1154.0     V102          NaN
# 677    4271978830  2015-12-30T00:00:00      1159.0    V6123          NaN
# 678    4271978841  2015-12-30T00:00:00      1207.0     V166          NaN
# 680    4271978863  2015-12-30T00:00:00      1231.0     V212          NaN
# 681    4271978874  2015-12-30T00:00:00      1232.0     V207          NaN
# 682    4271978885  2015-12-30T00:00:00      1235.0   V27610          NaN
# ...

# %%
violationCodeSubsetWestern_df.shape
# Out:
# (404697, 19)
